# %% [markdown]
# # Задача о погоне

# %% [markdown]
# ### Подключаю библиотеки

# %%
import math
from math import *

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %% [markdown]
# ### Вариант

# %%
print("Мой вариант: ",1032182534%70+1)
# Out:
# Мой вариант:  55

# %%
fi=3*math.pi/4

# %%
def dr (r, theta):
    return r/sqrt(22.04) #движение катера

# %%
r00=17.8/5.8
tetha1=np.arange(0, 2*math.pi,0.01)
r1=odeint(dr, r00,tetha1)

# %%
r01=17,8/3,8
tetha2=np.arange(-math.pi, math.pi,0.01)
r2=odeint(dr, r01,tetha2)

# %%
def f2(t):
    xt=math.tan(fi)*t
    return xt

t=np.arange(0, 20, 1)
r3=np.sqrt(t*t+f2(t)*f2(t))
tetha3=(np.tan(f2(t)/t))** (-1)
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
#Движение катера и лодки в первом случае
plt.polar(tetha1, r1,'r') 
plt.polar(tetha3, r3,'b')

# %%
#Движение катера и лодки во втором случае
plt.polar(tetha2, r2,'r')
plt.polar(tetha3, r3,'b')
